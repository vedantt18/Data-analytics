# %%
import pandas as pd

# Load the dataset
df = pd.read_csv("Bank Marketing.csv")

# Display the first 5 rows
print(df.head())
# Out:
#       banking marketing Unnamed: 1                    Unnamed: 2 Unnamed: 3  \
# 0  customer id and age.        NaN  Customer salary and balance.        NaN
# 1            customerid        age                        salary    balance
# 2                     1         58                        100000       2143
# 3                     2         44                         60000         29
# 4                     3         33                        120000          2
#
#                                           Unnamed: 4              Unnamed: 5  \
# 0  Customer marital status and job with education...                     NaN
# 1                                            marital                  jobedu
# 2                                            married     management,tertiary
# 3                                             single    technician,secondary
# 4                                            married  entrepreneur,secondary
#
# ...

# %%
# Get dataset info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45213 entries, 0 to 45212
# Data columns (total 19 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   banking marketing  45213 non-null  object
#  1   Unnamed: 1         45192 non-null  object
#  2   Unnamed: 2         45213 non-null  object
#  3   Unnamed: 3         45212 non-null  object
#  4   Unnamed: 4         45213 non-null  object
#  5   Unnamed: 5         45212 non-null  object
#  6   Unnamed: 6         45213 non-null  object
#  7   Unnamed: 7         45212 non-null  object
#  8   Unnamed: 8         45213 non-null  object
#  9   Unnamed: 9         45212 non-null  object
#  10  Unnamed: 10        45213 non-null  object
#  11  Unnamed: 11        45212 non-null  object
#  12  Unnamed: 12        45163 non-null  object
#  13  Unnamed: 13        45213 non-null  object
#  14  Unnamed: 14        45212 non-null  object
#  15  Unnamed: 15        45212 non-null  object
# ...

# %%
# Get descriptive statistics for numerical columns
df.describe()
# Out:
#         banking marketing Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# count               45213      45192      45213      45212      45213
# unique              45213        145         24      10335          5
# top                 45211         32      20000          0    married
# freq                    1       1509       7290       2767      27214
#
#                  Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  \
# count                 45212      45213      45212      45213      45212
# unique                   49          4          3          4          3
# top     management,tertiary        yes         no        yes         no
# freq                   7801      37091      44396      25130      37967
#
#        Unnamed: 10 Unnamed: 11 Unnamed: 12 Unnamed: 13 Unnamed: 14  \
# count        45213       45212       45163       45213       45212
# unique           5          63          14        2648          67
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Histogram of 'age'
plt.figure(figsize=(8, 6))
sns.histplot(df['age'], kde=True)
plt.title('Distribution of Age')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# Countplot of 'marital' status
plt.figure(figsize=(8, 6))
sns.countplot(x='marital', data=df)
plt.title('Count of Marital Status')
plt.xlabel('Marital Status')
plt.ylabel('Count')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'age'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-6-7da2217b285b> in <cell line: 0>()
#       4 # Histogram of 'age'
#       5 plt.figure(figsize=(8, 6))
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd # Ensure pandas is imported

# Load the dataset
df = pd.read_csv("Bank Marketing.csv")

# Display the first 5 rows
print(df.head())

# Get dataset info
df.info()

# Get descriptive statistics for numerical columns
df.describe()

# Print the column names to verify the correct spelling
print(df.columns)

# Histogram of 'age' - Assuming the column name is 'age' based on the original code
# If the column name is different, replace 'age' below with the correct name found in df.columns
plt.figure(figsize=(8, 6))
sns.histplot(df['age'], kde=True)
plt.title('Distribution of Age')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# Countplot of 'marital' status
plt.figure(figsize=(8, 6))
sns.countplot(x='marital', data=df)
plt.title('Count of Marital Status')
plt.xlabel('Marital Status')
plt.ylabel('Count')
plt.show()
# Out:
# <ipython-input-7-0a48a44165f1>:6: DtypeWarning: Columns (0,1,2,3,11,14,15,16) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("Bank Marketing.csv")
#       banking marketing Unnamed: 1                    Unnamed: 2 Unnamed: 3  \
# 0  customer id and age.        NaN  Customer salary and balance.        NaN
# 1            customerid        age                        salary    balance
# 2                     1         58                        100000       2143
# 3                     2         44                         60000         29
# 4                     3         33                        120000          2
#
#                                           Unnamed: 4              Unnamed: 5  \
# 0  Customer marital status and job with education...                     NaN
# 1                                            marital                  jobedu
# 2                                            married     management,tertiary
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd # Ensure pandas is imported

# Load the dataset
df = pd.read_csv("Bank Marketing.csv")

# Display the first 5 rows
print(df.head())

# Get dataset info
df.info()

# Get descriptive statistics for numerical columns
df.describe()

# Print the column names to verify the correct spelling
print(df.columns) # Print column names BEFORE attempting to access 'duration'

# Histogram of 'duration' - Assuming the column name is 'duration'
# If the column name is different, replace 'duration' below with the correct name found in df.columns
plt.figure(figsize=(8, 6))
# Replace 'duration' with the correct column name if it's different
sns.histplot(df['duration'], kde=True)
plt.title('Distribution of Duration')
plt.xlabel('Duration')
plt.ylabel('Frequency')
plt.show()

# Countplot of 'marital' status
plt.figure(figsize=(8, 6))
# Replace 'marital' with the correct column name if it's different
sns.countplot(x='marital', data=df)
plt.title('Count of Marital Status')
plt.xlabel('Marital Status')
plt.ylabel('Count')
plt.show()
# Out:
# <ipython-input-8-6f1b6e41d5b3>:6: DtypeWarning: Columns (0,1,2,3,11,14,15,16) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("Bank Marketing.csv")
#       banking marketing Unnamed: 1                    Unnamed: 2 Unnamed: 3  \
# 0  customer id and age.        NaN  Customer salary and balance.        NaN
# 1            customerid        age                        salary    balance
# 2                     1         58                        100000       2143
# 3                     2         44                         60000         29
# 4                     3         33                        120000          2
#
#                                           Unnamed: 4              Unnamed: 5  \
# 0  Customer marital status and job with education...                     NaN
# 1                                            marital                  jobedu
# 2                                            married     management,tertiary
# ...
